# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
from scipy.misc import imread

# %%
trace_image = imread('../data/anzhen/process_512x624/3374894_Z.jpg')
fig, ax = subplots()
ax.imshow(trace_image)
ax.add_patch(Polygon(trace_points.astype('float64'), 
                           facecolor='none', edgecolor='r', lw=2))

# %%
ax.add

# %%
trace_points = pd.read_csv('../data/anzhen/abnormal_Z/heart_traces/3374894_Z.jpg.txt', header=None).values

# %%
trace_points
# Out:
# array([[245, 130],
#        [218, 221],
#        [218, 308],
#        [202, 312],
#        [211, 345],
#        [201, 361],
#        [205, 325],
#        [183, 333],
#        [191, 369],
#        [206, 363],
#        [201, 400],
#        [222, 377],
#        [208, 413],
#        [318, 470],
#        [328, 457],
#        [366, 459],
#        [359, 483],
#        [424, 481],
#        [404, 455],
#        [436, 458],
#        [442, 426],
#        [425, 443],
#        [407, 397],
#        [427, 400],
#        [435, 383],
#        [411, 356],
#        [419, 324],
#        [399, 307],
#        [352, 306],
#        [387, 301],
#        [387, 289],
#        [353, 261],
#        [367, 217],
#        [350, 215],
#        [328, 164],
#        [332, 130]])

# %%
fig.images
# Out:
# []

# %%
fig.canvas.get_width_height()
# Out:
# (720, 720)

# %%
fig.patch.

# %%
import cv2

# %%
mask = np.zeros((624, 512), dtype='float32')
mask = np.copy(trace_image)
mask = cv2.fillPoly(mask, [trace_points.reshape((-1,1,2))], color=[255, 255, 255])
imshow(mask, cmap=cm.Greys)

# %%
trace_image.dtype
# Out:
# dtype('uint8')
